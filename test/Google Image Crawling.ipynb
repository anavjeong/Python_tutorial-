# %%
pip install bs4

# %%
pip install requests

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import urllib.request as urllib
import pandas as pd

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
elem = driver.find_element(By.NAME, "q")
elem.send_keys("주차안내")
elem.send_keys(Keys.RETURN)

# %%
images = driver.find_elements(By.CSS_SELECTOR,".rg_i.Q4LuWd")

count = 1
for image in images:
    image.click()
    time.sleep(3)
    imgURL = driver.find_element(By.CSS_SELECTOR,".n3VNCb").get_attribute("src")
    urllib.urlretrieve(imgURL, str(count) + "test.jpg")
    count = count + 1


SCROLL_PAUSE_TIME = 2

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element(By.CSS_SELECTOR,'.mye4qd').click
        except: 
            break
    last_height = new_height

# %%
titles = driver.find_elements(By.CSS_SELECTOR, '.OztcRd.goedYd.cS4Vcb-pGL6qe-mji9Ze')
title = []
names = driver.find_elements(By.CSS_SELECTOR, '.dmeZbb')
name = []


for title in titles:
    for name in names:
        print(name.text)
        print(title.text)
# Out:
# 바른병원
# 주차안내 | 바른병원
# 연세세인트성형외과
# 주차안내 | 바른병원
# 부산치과, 부산임플란트 시에스cs치과병원 임플란트ㅣ 부산전체임플란트, 부산디지털임플란트
# 주차안내 | 바른병원
# 곱창전문점 곱
# 주차안내 | 바른병원
# 안양도시공사
# 주차안내 | 바른병원
# 마포푸르메스포츠센터
# 주차안내 | 바른병원
# 큐병원
# 주차안내 | 바른병원
# 네이버 블로그
# 주차안내 | 바른병원
# CGV
# 주차안내 | 바른병원
# 구미시청
# 주차안내 | 바른병원
# 안산효요양병원
# 주차안내 | 바른병원
# 네이버 블로그
# 주차안내 | 바른병원
# 월화고기
# 주차안내 | 바른병원
# 삼성미즈산후조리원
# 주차안내 | 바른병원
# 경희재활요양병원
# 주차안내 | 바른병원
# 경기도의료원
# 주차안내 | 바른병원
# 분당척병원
# 주차안내 | 바른병원
# 서울창업디딤터
# 주차안내 | 바른병원
# 광주바로병원
# 주차안내 | 바른병원
# www.sisul.or.kr
# 주차안내 | 바른병원
# 윌스기념병원
# 주차안내 | 바른병원
# 힘찬병원
# 주차안내 | 바른병원
# 유승박.김경진내과
# 주차안내 | 바른병원
# 건국대학교병원
# 주차안내 | 바른병원
# NEWS 글보기 > 서비스도시
# 주차안내 | 바른병원
# 송파어린이문화회관
# 주차안내 | 바른병원
# 서울주얼리산업협동조합
# 주차안내 | 바른병원
# GM제일산부인과
# 주차안내 | 바른병원
# 충북을 새롭게, 도민을 신나게 충청북도 홈페이지
# 주차안내 | 바른병원
# 분야별정보 - 서울시
# 주차안내 | 바른병원
# 코엑스 ORGANIZER
# 주차안내 | 바른병원
# www.airport.kr
# 주차안내 | 바른병원
# 영진전문대학교 응급구조교육센터
# 주차안내 | 바른병원
# 희명병원
# 주차안내 | 바른병원
# 원광대학교병원
# 주차안내 | 바른병원
# 덕근닷컴
# 주차안내 | 바른병원
# 치카비
# 주차안내 | 바른병원
# 경향하우징페어
# 주차안내 | 바른병원
# ...

# %%
driver.find_element(By.CSS_SELECTOR, '.OztcRd.goedYd.cS4Vcb-pGL6qe-mji9Ze').text
# Out:
# '주차안내 | 바른병원'

# %%
driver.find_element(By.CSS_SELECTOR, '.dmeZbb').text
# Out:
# '바른병원'

# %%
#공통인 url부분을 변수로 선언
url = "https://sports.news.naver.com/kbaseball/record/index?category=kbo&year="

df = pd.DataFrame([]) # for문의 결과물을 담을 빈데이터프레임
for i in range(2015, 2022): # 2015 이상 2022 미만의 모든 정수를 리스트로
    df1 = pd.read_html(url + str(i))[0] # i문자형으로, [0]으로 인덱싱
    df1["연도"] = str(i) # 연도 항목이 없어서 열로 추가
    df = pd.concat([df, df1])
df = df.replace({"kt":"KT", "SK":"SSG", "넥센":"키움"}) # 팀명이 바뀐팀들의 팀명 수정
df.pivot(values="순위", index="연도", columns="팀")
df.pivot(values="팀", index="연도", columns="순위")

# %%
df = pd.DataFrame([])
